# %% [markdown]
# ## Lendo os arquivos works

# %%
import os
import json
from pprint import pprint
import pandas as pd

# %%
file = 'files/d207629c-37c0-4337-b87c-af08b4dc168a.json'
# file = 'files/132753ff-5294-4a79-bc81-8e89b94a215c.json'

# %%
with open(file, 'r') as f:
    data = f.read()
#     print(data)
    fs = json.loads(data)    
#     print(fs)
    ds = pd.DataFrame(fs.items())

# %%
ds
# Out:
#                 0                                                  1
# 0           iswcs                                                 []
# 1              id               d207629c-37c0-4337-b87c-af08b4dc168a
# 2       languages                                              [eng]
# 3         type-id               f061270a-2fd6-32f1-a641-f0f8676d14e6
# 4       relations  [{'target-credit': '', 'ended': False, 'attrib...
# 5            type                                               Song
# 6      attributes  [{'type-id': '01eeee67-f514-3801-bdce-279e0487...
# 7           title                         The Underground in America
# 8        language                                                eng
# 9  disambiguation

# %%
# index 0 é o cabeçalho e 1 é corpo
ds[1][4]
# Out:
# [{'target-credit': '',
#   'ended': False,
#   'attributes': [],
#   'target-type': 'artist',
#   'attribute-ids': {},
#   'attribute-values': {},
#   'end': None,
#   'type': 'composer',
#   'begin': None,
#   'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#   'direction': 'backward',
#   'source-credit': '',
#   'artist': {'disambiguation': '',
#    'name': 'Phil Anselmo',
#    'id': '3e99e22f-3dc4-4b0c-b280-6f0bc7657474',
#    'sort-name': 'Anselmo, Phil'}},
#  {'attributes': [],
#   'ended': False,
#   'target-credit': '',
#   'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#   'begin': None,
#   'end': None,
#   'attribute-values': {},
#   'type': 'composer',
#   'target-type': 'artist',
#   'attribute-ids': {},
#   'direction': 'backward',
#   'source-credit': '',
#   'artist': {'sort-name': 'Dimebag Darrell',
#    'disambiguation': '',
#    'name': 'Dimebag Darrell',
#    'id': 'bded4d70-f13f-41ee-86b9-8c4514086acf'}},
#  {'target-credit': '',
#   'ended': False,
#   'attributes': [],
#   'target-type': 'artist',
#   'attribute-ids': {},
#   'attribute-values': {},
#   'end': None,
#   'type': 'composer',
#   'begin': None,
#   'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#   'source-credit': '',
#   'direction': 'backward',
#   'artist': {'sort-name': 'Brown, Rex',
#    'disambiguation': '',
#    'id': 'f98f937e-0e8d-41ab-89d2-03628c69a15e',
#    'name': 'Rex Brown'}},
#  {'end': None,
#   'attribute-values': {},
#   'type': 'composer',
#   'target-type': 'artist',
#   'attribute-ids': {},
#   'type-id': 'd59d99ea-23d4-4a80-b066-edca32ee158f',
#   'begin': None,
#   'target-credit': '',
#   'attributes': [],
#   'ended': False,
#   'artist': {'name': 'Vinnie Paul',
#    'id': 'fcefb8fb-05d9-4768-bf60-2e06c970f736',
#    'disambiguation': '',
#    'sort-name': 'Vinnie Paul'},
#   'direction': 'backward',
#   'source-credit': ''},
#  {'artist': {'id': '3e99e22f-3dc4-4b0c-b280-6f0bc7657474',
#    'name': 'Phil Anselmo',
#    'disambiguation': '',
#    'sort-name': 'Anselmo, Phil'},
#   'direction': 'backward',
#   'source-credit': '',
#   'attribute-ids': {},
#   'target-type': 'artist',
#   'end': None,
#   'attribute-values': {},
#   'type': 'lyricist',
#   'begin': None,
#   'type-id': '3e48faba-ec01-47fd-8e89-30e81161661c',
#   'target-credit': '',
#   'ended': False,
#   'attributes': []},
#  {'attributes': [],
#   'ended': False,
#   'target-credit': '',
#   'type-id': '3e48faba-ec01-47fd-8e89-30e81161661c',
#   'begin': None,
#   'end': None,
#   'attribute-values': {},
#   'type': 'lyricist',
#   'attribute-ids': {},
#   'target-type': 'artist',
#   'direction': 'backward',
#   'source-credit': '',
#   'artist': {'disambiguation': '',
#    'id': 'bded4d70-f13f-41ee-86b9-8c4514086acf',
#    'name': 'Dimebag Darrell',
#    'sort-name': 'Dimebag Darrell'}},
#  {'attributes': [],
#   'ended': False,
#   'target-credit': '',
#   'type-id': '3e48faba-ec01-47fd-8e89-30e81161661c',
#   'begin': None,
#   'end': None,
#   'attribute-values': {},
#   'type': 'lyricist',
#   'target-type': 'artist',
#   'attribute-ids': {},
#   'source-credit': '',
#   'direction': 'backward',
#   'artist': {'sort-name': 'Brown, Rex',
#    'disambiguation': '',
#    'id': 'f98f937e-0e8d-41ab-89d2-03628c69a15e',
#    'name': 'Rex Brown'}},
#  {'target-type': 'artist',
#   'attribute-ids': {},
#   'attribute-values': {},
#   'end': None,
#   'type': 'lyricist',
#   'begin': None,
#   'type-id': '3e48faba-ec01-47fd-8e89-30e81161661c',
#   'target-credit': '',
#   'ended': False,
#   'attributes': [],
#   'artist': {'disambiguation': '',
#    'id': 'fcefb8fb-05d9-4768-bf60-2e06c970f736',
#    'name': 'Vinnie Paul',
#    'sort-name': 'Vinnie Paul'},
#   'source-credit': '',
#   'direction': 'backward'},
#  {'direction': 'backward',
#   'source-credit': '',
#   'recording': {'title': 'The Underground in America (Early Mix)',
#    'id': '1e3e5274-64ba-49b4-90ac-7a33ddc82bd6',
#    'disambiguation': '',
#    'video': False,
#    'length': 237000},
#   'target-type': 'recording',
#   'attribute-ids': {},
#   'type': 'performance',
#   'attribute-values': {},
#   'end': None,
#   'begin': None,
#   'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#   'target-credit': '',
#   'ended': False,
#   'attributes': []},
#  {'direction': 'backward',
#   'source-credit': '',
#   'recording': {'video': False,
#    'disambiguation': '',
#    'id': '38d88a9b-9ea6-44bc-aafc-3de8b8d8e25b',
#    'title': 'The Underground in America',
#    'length': 273800},
#   'type': 'performance',
#   'attribute-values': {},
#   'end': None,
#   'target-type': 'recording',
#   'attribute-ids': {},
#   'type-id': 'a3005666-a872-32c3-ad06-98af558e99b0',
#   'begin': None,
#   'target-credit': '',
#   'attributes': [],
#   'ended': False}]

# %%
# with open(file, 'r')as fl:
# works = json.loads(str(f.read()))
# works
# for i in fs:
#     print(i['id'])
ds
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
# 0    10 non-null object
# 1    10 non-null object
# dtypes: object(2)
# memory usage: 240.0+ bytes
