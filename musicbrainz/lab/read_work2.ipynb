# %%
import os
import json
from pprint import pprint
import pandas as pd

# %%
file = '38697076-780a-4742-b3b2-06b79a522741.json'

# %%
with open(file, 'r')as f:
    data = f.read()
    fs = json.loads(data)

# %%
ds = pd.DataFrame(fs.items())
# ds = pd.DataFrame(fs['relations'])
# df = pd.DataFrame(ds['artist'])
ds
# Out:
#                 0                                                  1
# 0         type-id               f061270a-2fd6-32f1-a641-f0f8676d14e6
# 1       languages                                              [eng]
# 2  disambiguation
# 3            type                                               Song
# 4              id               38697076-780a-4742-b3b2-06b79a522741
# 5           title                                    Bulls on Parade
# 6           iswcs                                  [T-070.249.297-4]
# 7      attributes  [{'value': '3980652-001', 'type': 'GEMA ID', '...
# 8       relations  [{'direction': 'backward', 'type-id': 'd59d99e...
# 9        language                                                eng

# %%
df = pd.DataFrame(fs['relations'])
df
# Out:
#                                                artist  \
# 0   {'id': '42a636a0-dbe4-4d0c-abe2-1590fad9531b',...
# 1   {'name': 'Tim Commerford', 'id': '4d61abe3-ce6...
# 2   {'name': 'Zack de la Rocha', 'id': 'aa659468-d...
# 3   {'sort-name': 'Wilk, Brad', 'disambiguation': ...
# 4   {'sort-name': 'Rocha, Zack de la', 'disambigua...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...
